# %% [markdown]
# ## Importing Libraries

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data = './data.yaml', epochs=10)
# Out:
# Ultralytics YOLOv8.0.99  Python-3.10.10 torch-2.0.1+cpu CPU
# ...

# %%
from IPython.display import Image

Image('./runs/detect/train/confusion_matrix_normalized.png')
