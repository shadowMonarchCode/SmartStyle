# %%
from ultralytics import YOLO
from IPython.display import Image

# Loading model with pretrained weights
model = YOLO('./runs/detect/train/weights/best.pt')

# %% [markdown]
# ### Validation on validation dataset

# %%
model.val(data='data.yaml')
# Out:
# Ultralytics YOLOv8.0.99  Python-3.10.10 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\rishu\Projects\SmartStyle2\data\labels\val.cache... 1051 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1051/1051 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 66/66 [02:40<00:00,  2.43s/it]
#                    all       1051       1879      0.733      0.606      0.669      0.535
#       short sleeve top       1051        388      0.802      0.928      0.943      0.782
#        long sleeve top       1051        226      0.822      0.704       0.83      0.632
#   short sleeve outwear       1051          5          1          0      0.318      0.315
#    long sleeve outwear       1051         75      0.695      0.791      0.825      0.605
#                   vest       1051         67      0.591      0.791       0.73      0.584
# ...

# %%
Image('./runs/detect/val/confusion_matrix_normalized.png')

# %% [markdown]
# ### Validation on training dataset

# %%
model.val(data='coco.yaml')
# Out:
# Ultralytics YOLOv8.0.99  Python-3.10.10 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\rishu\Projects\SmartStyle2\data\labels\train.cache... 4946 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4946/4946 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 310/310 [11:53<00:00,  2.30s/it]
#                    all       4946       8972      0.798      0.645      0.726      0.591
#       short sleeve top       4946       1891      0.832      0.907      0.943      0.793
#        long sleeve top       4946       1031      0.865      0.767      0.896      0.718
#   short sleeve outwear       4946         20          1          0       0.34      0.301
#    long sleeve outwear       4946        393      0.687       0.82      0.839      0.671
#                   vest       4946        368      0.711      0.827      0.831      0.617
# ...

# %%
Image('./runs/detect/val2/confusion_matrix_normalized.png')
